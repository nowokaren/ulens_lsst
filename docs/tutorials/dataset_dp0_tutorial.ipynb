# %% [markdown]
# # DP0.2 Recovered microlensing simulated light curves dataset
#
# This dataset comprises 43 runs, each containing 2500 simulated microlensing events within a circular region of 0.1-degree radius centered at different points on the footprint of [Data Preview 0.2 (DP0.2)](https://dp0-2.lsst.io) simulated region by the Vera C. Rubin Observatory. For general information about the DP0 program, visit [dp0.lsst.io](https://dp0.lsst.io).
#
# ## Dataset description
#
# The dataset includes four system types: `BS` (Binary Star), `FFP` (Free-Floating Planets), `BH` (Black Holes), and `PS` (Planetary system). Each system type is simulated using a specific microlensing model (e.g., PSPL, FSPL, USBL) with parameters computed using functions from the [`ulens_utils.py` module](https://github.com/nowokaren/ulens_lsst/blob/main/ulens_lsst/ulens_utils.py) (source: Anibal Varela).
#
# Each simulated light curve is generated from an average of 450 sources injected into and extracted from DP0.2 images (termed `calexp`) which contains the respective event. The injection process uses the [`VisitInjectTask`](https://pipelines.lsst.io/modules/lsst.source.injection/tasks/lsst.source.injection.VisitInjectTask.html), which injects synthetic sources into single-frame visits using the GalSim package. Measurements are performed using the [`ForcedMeasurementTask`](https://pipelines.lsst.io/modules/lsst.meas.base/tasks/lsst.meas.base.forcedMeasurement.ForcedMeasurementTask.html), which measure sources flux and other properties based on a reference catalog.
#
# ## Data Files
# Files can be downloaded [here](https://drive.google.com/drive/folders/1eUMx8DjK1jftuTQGW7PhYC7zLMrZDJPP?usp=sharing).
#
# - **`dp0_data-events.parquet`**: Contains event metadata, including coordinates (`ra`, `dec`), system type, model, and microlensing parameters
#     - columns starting with
#         - `param_`: simulated parameters using a predefined microlensing parameters from Genulens, others with a defined distribution corresponding to the system type and AstroDataLab sources catalog.
#         - `param-pylima_`: retrived pyLIMA parameters after simulation
# - **`dp0_calexps-photometry.parquet`**: Contains photometry data, including simulated magnitudes, measured magnitudes (`meas_mag`), errors, and flags for each event.

# %%
import pyarrow.parquet as pq

events_file = 'dp0_data-events.parquet'
table = pq.read_table(events_file)
print(f'{"Column":25} {"Type":7} Description')
print("-"*50)

for field in table.schema:
    desc = field.metadata.get(b'description', b'').decode() if field.metadata else ''
    print(f'{field.name:25} {str(field.type):7} {desc}')
# Out:
# Column                    Type    Description
# --------------------------------------------------
# event_id                  int64   Unique identifier for the microlensing event.
# ra                        double  Right ascension of the event source (degrees).
# dec                       double  Declination of the event source (degrees).
# model                     string  Microlensing model type (e.g., PSPL, FSPL).
# system_type               string  Type of lensing system (e.g., PS, BS, BH, FFP).
# points                    int64   Number of data points in the light curve.
# logL                      double  Logarithm of the luminosity of the source star.
# logTe                     double  Logarithm of the effective temperature of the source star.
# D_L                       double  Distance to the lens (kpc).
# D_S                       double  Distance to the source (kpc).
# mu_rel                    double  Relative proper motion between lens and source (mas/yr).
# cadence_noise             string  Description of the observational cadence and noise model.
# peak_time                 double  Time of the peak magnification (JD).
# param_u                   double  Source magnitude in the u band.
# param_g                   double  Source magnitude in the g band.
# param_r                   double  Source magnitude in the r band.
# param_i                   double  Source magnitude in the i band.
# param_z                   double  Source magnitude in the z band.
# param_y                   double  Source magnitude in the y band.
# param_t0                  double  Time of closest approach (JD).
# param_tE                  double  Einstein crossing time (days).
# param_u0                  double  Impact parameter (in units of Einstein radius).
# param_radius              double  Source star radius (solar radii).
# param_q                   double  Mass ratio between lens components (for binary lenses).
# param_rho                 double  Source radius in units of Einstein radius.
# param_s                   double  Projected separation between lens components (in Einstein radius units).
# param_alpha               double  Angle of the source trajectory relative to the lens axis (radians).
# param_piEE                double  Microlensing parallax component (east).
# param_piEN                double  Microlensing parallax component (north).
# param_f_blend             double  Blending flux fraction.
# param_mass_star           double  Mass of the lens star (solar masses).
# param_mass_planet         double  Mass of the lens planet (solar masses).
# param_thetaE              double  Einstein radius angle (mas).
# param-pylima_t_center     double  pyLIMA model parameter: time of closest approach (JD).
# param-pylima_u_center     double  pyLIMA model parameter: impact parameter.
# param-pylima_tE           double  pyLIMA model parameter: Einstein crossing time (days).
# param-pylima_rho          double  pyLIMA model parameter: source radius (Einstein radius units).
# param-pylima_separation   double  pyLIMA model parameter: lens separation (Einstein radius units).
# param-pylima_mass_ratio   double  pyLIMA model parameter: mass ratio of lens components.
# param-pylima_alpha        double  pyLIMA model parameter: trajectory angle (radians).
# param-pylima_piEN         double  pyLIMA model parameter: parallax component (north).
# param-pylima_piEE         double  pyLIMA model parameter: parallax component (east).
# param-pylima_fsource_u    double  pyLIMA model parameter: source flux in u band.
# param-pylima_ftotal_u     double  pyLIMA model parameter: total flux in u band.
# param-pylima_fsource_g    double  pyLIMA model parameter: source flux in g band.
# param-pylima_ftotal_g     double  pyLIMA model parameter: total flux in g band.
# param-pylima_fsource_r    double  pyLIMA model parameter: source flux in r band.
# param-pylima_ftotal_r     double  pyLIMA model parameter: total flux in r band.
# param-pylima_fsource_i    double  pyLIMA model parameter: source flux in i band.
# param-pylima_ftotal_i     double  pyLIMA model parameter: total flux in i band.
# param-pylima_fsource_z    double  pyLIMA model parameter: source flux in z band.
# param-pylima_ftotal_z     double  pyLIMA model parameter: total flux in z band.
# param-pylima_fsource_y    double  pyLIMA model parameter: source flux in y band.
# param-pylima_ftotal_y     double  pyLIMA model parameter: total flux in y band.
# param-pylima_t0           double  pyLIMA model parameter: time of closest approach (JD).
# param-pylima_u0           double  pyLIMA model parameter: impact parameter.
# param-pylima_fblend_u     double  pyLIMA model parameter: blend flux in u band.
# param-pylima_gblend_u     double  pyLIMA model parameter: blend flux gradient in u band.
# param-pylima_fblend_g     double  pyLIMA model parameter: blend flux in g band.
# param-pylima_gblend_g     double  pyLIMA model parameter: blend flux gradient in g band.
# param-pylima_fblend_r     double  pyLIMA model parameter: blend flux in r band.
# param-pylima_gblend_r     double  pyLIMA model parameter: blend flux gradient in r band.
# param-pylima_fblend_i     double  pyLIMA model parameter: blend flux in i band.
# param-pylima_gblend_i     double  pyLIMA model parameter: blend flux gradient in i band.
# param-pylima_fblend_z     double  pyLIMA model parameter: blend flux in z band.
# param-pylima_gblend_z     double  pyLIMA model parameter: blend flux gradient in z band.
# param-pylima_fblend_y     double  pyLIMA model parameter: blend flux in y band.
# param-pylima_gblend_y     double  pyLIMA model parameter: blend flux gradient in y band.
# nearby_object_ra          double  Right ascension of nearby object (degrees).
# nearby_object_dec         double  Declination of nearby object (degrees).
# nearby_object_objId       int64   Unique identifier for nearby object.
# nearby_object_mag_u       double  Magnitude of nearby object in u band.
# nearby_object_mag_err_u   double  Magnitude error of nearby object in u band.
# nearby_object_fwhm_u      double  FWHM of nearby object in u band (arcseconds).
# nearby_object_mag_g       double  Magnitude of nearby object in g band.
# nearby_object_mag_err_g   double  Magnitude error of nearby object in g band.
# nearby_object_fwhm_g      double  FWHM of nearby object in g band (arcseconds).
# nearby_object_mag_r       double  Magnitude of nearby object in r band.
# nearby_object_mag_err_r   double  Magnitude error of nearby object in r band.
# nearby_object_fwhm_r      double  FWHM of nearby object in r band (arcseconds).
# nearby_object_mag_i       double  Magnitude of nearby object in i band.
# nearby_object_mag_err_i   double  Magnitude error of nearby object in i band.
# nearby_object_fwhm_i      double  FWHM of nearby object in i band (arcseconds).
# nearby_object_mag_z       double  Magnitude of nearby object in z band.
# nearby_object_mag_err_z   double  Magnitude error of nearby object in z band.
# nearby_object_fwhm_z      double  FWHM of nearby object in z band (arcseconds).
# nearby_object_mag_y       double  Magnitude of nearby object in y band.
# nearby_object_mag_err_y   double  Magnitude error of nearby object in y band.
# nearby_object_fwhm_y      double  FWHM of nearby object in y band (arcseconds).
# nearby_object_distance    double  Distance to nearby object (arcseconds).

# %%
photo_path='dp0_calexps-photometry.parquet'
table = pq.read_table(photo_path)
print(f'{"Column":25} {"Type":7} Description')
print("-"*50)

for field in table.schema:
    desc = field.metadata.get(b'description', b'').decode() if field.metadata else ''
    print(f'{field.name:25} {str(field.type):7} {desc}')
# Out:
# Column                    Type    Description
# --------------------------------------------------
# event_id                  int64   Unique identifier for the microlensing event.
# calexp_id                 int64   Unique identifier for the calibrated exposure.
# time                      double  Observation time (JD).
# band                      string  Photometric band (e.g., u, g, r, i, z, y).
# ideal_mag                 double  Ideal (unblended) magnitude of the source.
# meas_mag                  double  Measured magnitude including blending.
# meas_mag_err              double  Error in the measured magnitude.
# meas_flux                 double  Measured flux of the source.
# meas_flux_err             double  Error in the measured flux.
# magnification             double  Microlensing magnification factor at the observation time.
# injection_flag            int64   Indicates whether the data point had any flag during injection (non-zero) or 0 if none.
# measure_flag              string  Flag describing the measurement flags if any, else "".
# mag_lim                   double  Limiting magnitude of the observation.

# %% [markdown]
# ### Data set visualization

# %% [markdown]
# #### Sky map with injected events
#
# The 43 simulations are shown on the same sky map. Each event is represented by a dot, with the color indicating its system type. Since the events within a single simulation are much closer to each other than the distance between different simulations, each simulation appears as a “thick” or clustered dot on the map.

# %%
import pyarrow.parquet as pq
import pyarrow.compute as pc
import numpy as np
import matplotlib.pyplot as plt

events_table = pq.read_table(
    events_file,
    columns=['event_id', 'ra', 'dec', 'system_type', 'model', 'points']
)
if not events_table:
    raise ValueError(f"No data found in {events_path}")

events_data = events_table.to_pandas()
ra = events_data['ra'].to_numpy()
dec = events_data['dec'].to_numpy()
system_types = events_data['system_type'].to_numpy()
models = events_data['model'].to_numpy()
points = events_data['points'].to_numpy()

system_type_labels = np.array([f"{st} ({m})" for st, m in zip(system_types, models)])
unique_system_types = np.unique(system_type_labels)

fig, ax = plt.subplots(figsize=(10,10))

colors = plt.colormaps['tab10']
system_type_colors = {stype: colors(i % 10) for i, stype in enumerate(unique_system_types)}

for system_type in unique_system_types:
    mask = system_type_labels == system_type
    ax.scatter(
        ra[mask],
        dec[mask],
        s=3,
        c=[system_type_colors[system_type]],
        label=system_type
    )
    
ax.set_xlabel('Right Ascension (deg)')
ax.set_ylabel('Declination (deg)')
ax.set_title('Sky map of microlensing events (DP0.2)')
ax.grid(True, alpha=0.3)
ax.legend(title='System Type (Model)', loc='best')

plt.show()

# %% [markdown]
# #### Event plotting
# The plot_event function shows how to filter an event from data files and plots it measured and ideal light curves (LCs).

# %%
import os
import matplotlib.pyplot as plt
import pyarrow.parquet as pq

def plot_event(event_id, events_path='dp0_data-events.parquet',
               photometry_path='dp0_calexps-photometry.parquet',
               bands=None, filter_flags=False, ax=None,
               colors=None, comment=""):

    colors = colors or {"u":"purple","g":"green","r":"red","i":"orange","z":"brown","y":"blue"}

    filters = [('event_id', '=', event_id)]
    events_df = pq.read_table(events_path, filters=filters).to_pandas()
    photometry_df = pq.read_table(photometry_path, filters=filters).to_pandas()

    if filter_flags:
        photometry_df = photometry_df[(photometry_df['measure_flag']=='') & 
                                      (photometry_df['injection_flag']==0)]

    bands = bands or sorted(photometry_df['band'].unique())
    ax = ax or plt.subplots(figsize=(8,6))[1]

    for band in bands:
        data = photometry_df[photometry_df['band']==band]
        ax.errorbar(data['time'], data['meas_mag'], yerr=abs(data['meas_mag_err']),
                    fmt='o', ms=3, color=colors.get(band,'black'), 
                    alpha=0.5, label=f'{band}_meas')
        ax.plot(data['time'], data['ideal_mag'], '.', ms=1, 
                color=colors.get(band,'black'), label=f'{band}_ideal')

    event = events_df.iloc[0]
    ax.set_xlabel('Time (MJD)')
    ax.set_ylabel('Magnitude')
    ax.invert_yaxis()
    ax.set_title(f'Event {event_id} ({event["system_type"]} - {event["model"]})' + " - " + comment)
    ax.legend(loc=(1.01,0))
    ax.grid(alpha=0.3)

    return ax

# %% [markdown]
# Some sources were flagged during the injection or measurement steps. The event can be plotted either complete, including all points, or cleaned, excluding the flagged points.

# %%
plot_event(
    event_id=123,
    filter_flags=False,
    comment="complete LCs"
)

plot_event(
    event_id=123,
    filter_flags=True,
    comment="cleaned from flagged dots"
)
# Out:
# <Axes: title={'center': 'Event 123 (PS - USBL)cleaned from flagged dots'}, xlabel='Time (MJD)', ylabel='Magnitude'>

# %% [markdown]
# #### Parameter distribution
#
# Histograms for each simulated parameter are shown below. Some parameters were generated by Genulens, while others were drawn from a defined uniform distribution depending on the system type. Histograms are also shown for pyLIMA parameters retrieved after the simulation.

# %%
import pyarrow.parquet as pq
import matplotlib.pyplot as plt


de = pq.read_table(events_file).to_pandas()

param_cols = [col for col in de.columns if "param" in col and "blend" not in col.lower()]

system_types = de['system_type'].unique()
colors = plt.cm.tab10.colors

for col in param_cols:
    plt.figure(figsize=(6,6))
    plt.title(col)
    
    for i, stype in enumerate(system_types):
        subset = de[de['system_type'] == stype][col].dropna() 
        if len(subset) <= 1:
            continue 
        plt.hist(subset, bins=50, histtype='step', 
                 color=colors[i % len(colors)], label=stype, linewidth=1.5)
    
    plt.legend()
    plt.show()
